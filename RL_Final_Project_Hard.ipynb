# %% [markdown]
# # IEOR 4575 Reinforcement Learning Project
# ## Integer Programming - Cutting Plane Problem [Easy Configuration]
# ---
# Submission by : Arunit Maity (am5689)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -a /content/drive/MyDrive/Project_learn2cut/Project_learn2cut/* /content/

# %%
# !pip install -i https://pypi.gurobi.com gurobipy
# Out:
# Looking in indexes: https://pypi.gurobi.com
# Collecting gurobipy
#   Downloading gurobipy-9.5.1-cp37-cp37m-manylinux2014_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 14.6 MB/s
# Installing collected packages: gurobipy
# Successfully installed gurobipy-9.5.1

# %%
import numpy as np
import gymenv_v2
from gymenv_v2 import make_multiple_env
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from time import time
import matplotlib.pyplot as plt

# %%
hard_config = {
    "load_dir"        : 'instances/train_100_n60_m60',
    "idx_list"        : list(range(99)),
    "timelimit"       : 50,
    "reward_type"     : 'obj'
}

# %%
# Define Helper Functions
def min_max_scaler(A, b, D, d):
    constraints = np.concatenate((A, D), axis=0)
    rhs = np.concatenate((b, d))
    max_1, max_2 = np.max(constraints), np.max(rhs)
    min_1, min_2 = np.min(constraints), np.min(rhs)
    norm_A = (A - min_1) / (max_1 - min_1)
    norm_D = (D - min_1) / (max_1 - min_1)
    norm_b = (b - min_2) / (max_2 - min_2)
    norm_d = (d - min_2) / (max_2 - min_2)
    return norm_A, norm_b, norm_D, norm_d

def discounted_rewards(r, gamma):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_sum = 0
    for i in reversed(range(0,len(r))):
        discounted_r[i] = running_sum * gamma + r[i]
        running_sum = discounted_r[i]
    return list(discounted_r)

# %%
# Define LSTM Layer
class lstm_layer(nn.Module):
    def __init__(self, input_size, hidden_size, bidirectional=False):
        super(lstm_layer, self).__init__()
        self.hidden_size = hidden_size
        self.input_size = input_size
        self.bidirectional = bidirectional
        self.lstm = nn.LSTM(input_size, hidden_size, bidirectional=bidirectional, batch_first=True)

    def forward(self, input):
        inputs = torch.FloatTensor(input).view(1, -1, self.input_size)
        output, _ = self.lstm(inputs)
        output = output[-1].reshape(-1, self.hidden_size)
        return output

# %%
# Define Long Short-Term Memory (LSTM) Neural Network with Attention for Q-Value prediction
class lstm_attention_net(nn.Module):
    def __init__(self, input_size, hidden_size_lstm, hidden_size_dense):
        super(lstm_attention_net, self).__init__()
        self.input_size = input_size
        self.hidden_size_lstm = hidden_size_lstm
        self.hidden_size_dense = hidden_size_dense
        self.lstm_A = lstm_layer(input_size, hidden_size_lstm)
        self.lstm_D = lstm_layer(input_size, hidden_size_lstm)
        self.linear_1 = nn.Linear(self.hidden_size_lstm, self.hidden_size_dense)
        self.sigmoid = nn.Sigmoid()

    def forward(self, constraints, cuts):
        constraints = torch.FloatTensor(constraints)
        cuts = torch.FloatTensor(cuts)
        lstm_op_A = self.lstm_A.forward(constraints)
        lstm_op_D = self.lstm_D.forward(cuts)
        A = self.sigmoid(self.linear_1(lstm_op_A))
        D = self.sigmoid(self.linear_1(lstm_op_D))
        attention = torch.sum(torch.mm(D, A.T), axis = -1)
        return attention

# %%
# Define Policy and required functions 
class Policy(object):
    def __init__(self, input_size, hidden_size_lstm, hidden_size_dense, lr):
        self.model = lstm_attention_net(input_size, hidden_size_lstm, hidden_size_dense)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)

    def compute_prob(self, constraints, cuts):
        constraints = torch.FloatTensor(constraints)
        cuts = torch.FloatTensor(cuts)
        prob = torch.nn.functional.softmax(self.model(constraints, cuts), dim=-1)
        return prob.cpu().data.numpy()

    def _to_one_hot(self, y, num_classes):
        scatter_dim = len(y.size())
        y_tensor = y.view(*y.size(), -1)
        zeros = torch.zeros(*y.size(), num_classes, dtype=y.dtype)
        return zeros.scatter(scatter_dim, y_tensor, 1)

    def train(self, constraints, cuts, actions, Qs):
        actions = torch.LongTensor(actions)
        Qs = torch.FloatTensor(Qs)
        total_loss = 0
        
        # Iterate over all constraints and cuts
        for i in range(len(constraints)):
            curr_constraints = constraints[i]
            curr_cuts = cuts[i]
            curr_action = actions[i]
            # Compute probabilities for actions 
            logits = self.model(curr_constraints, curr_cuts)
            prob = torch.nn.functional.softmax(logits, dim = -1)
            action_onehot = self._to_one_hot(curr_action, curr_cuts.shape[0])
            prob_selected = torch.sum(prob * action_onehot, axis = -1)
            prob_selected += 1e-8  # To avoid log(0) (in case prob = 0)
            loss = -torch.mean(Qs[i] * torch.log(prob_selected))
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
            total_loss += loss.detach().cpu().data.numpy()
        return total_loss

# %%
# Setup Environment, Actor and Inital Variable Values
env = make_multiple_env(**hard_config) 
lr = 1e-3
gamma = 0.98
input_dim = 61
lstm_hidden = 256
dense_hidden = 256
actor = Policy(input_size=input_dim, hidden_size_lstm=lstm_hidden, hidden_size_dense=dense_hidden, lr=lr)
rrecord = []
loss_record = []
reward_record = []
moving_average = []
# Out:
# loading training instances, dir instances/train_100_n60_m60 idx 0
# loading training instances, dir instances/train_100_n60_m60 idx 1
# loading training instances, dir instances/train_100_n60_m60 idx 2
# loading training instances, dir instances/train_100_n60_m60 idx 3
# loading training instances, dir instances/train_100_n60_m60 idx 4
# loading training instances, dir instances/train_100_n60_m60 idx 5
# loading training instances, dir instances/train_100_n60_m60 idx 6
# loading training instances, dir instances/train_100_n60_m60 idx 7
# loading training instances, dir instances/train_100_n60_m60 idx 8
# loading training instances, dir instances/train_100_n60_m60 idx 9
# loading training instances, dir instances/train_100_n60_m60 idx 10
# loading training instances, dir instances/train_100_n60_m60 idx 11
# loading training instances, dir instances/train_100_n60_m60 idx 12
# loading training instances, dir instances/train_100_n60_m60 idx 13
# loading training instances, dir instances/train_100_n60_m60 idx 14
# loading training instances, dir instances/train_100_n60_m60 idx 15
# loading training instances, dir instances/train_100_n60_m60 idx 16
# loading training instances, dir instances/train_100_n60_m60 idx 17
# loading training instances, dir instances/train_100_n60_m60 idx 18
# loading training instances, dir instances/train_100_n60_m60 idx 19
# loading training instances, dir instances/train_100_n60_m60 idx 20
# loading training instances, dir instances/train_100_n60_m60 idx 21
# loading training instances, dir instances/train_100_n60_m60 idx 22
# loading training instances, dir instances/train_100_n60_m60 idx 23
# loading training instances, dir instances/train_100_n60_m60 idx 24
# loading training instances, dir instances/train_100_n60_m60 idx 25
# loading training instances, dir instances/train_100_n60_m60 idx 26
# loading training instances, dir instances/train_100_n60_m60 idx 27
# loading training instances, dir instances/train_100_n60_m60 idx 28
# loading training instances, dir instances/train_100_n60_m60 idx 29
# loading training instances, dir instances/train_100_n60_m60 idx 30
# loading training instances, dir instances/train_100_n60_m60 idx 31
# loading training instances, dir instances/train_100_n60_m60 idx 32
# loading training instances, dir instances/train_100_n60_m60 idx 33
# loading training instances, dir instances/train_100_n60_m60 idx 34
# loading training instances, dir instances/train_100_n60_m60 idx 35
# loading training instances, dir instances/train_100_n60_m60 idx 36
# loading training instances, dir instances/train_100_n60_m60 idx 37
# loading training instances, dir instances/train_100_n60_m60 idx 38
# loading training instances, dir instances/train_100_n60_m60 idx 39
# loading training instances, dir instances/train_100_n60_m60 idx 40
# loading training instances, dir instances/train_100_n60_m60 idx 41
# loading training instances, dir instances/train_100_n60_m60 idx 42
# loading training instances, dir instances/train_100_n60_m60 idx 43
# loading training instances, dir instances/train_100_n60_m60 idx 44
# loading training instances, dir instances/train_100_n60_m60 idx 45
# loading training instances, dir instances/train_100_n60_m60 idx 46
# loading training instances, dir instances/train_100_n60_m60 idx 47
# loading training instances, dir instances/train_100_n60_m60 idx 48
# loading training instances, dir instances/train_100_n60_m60 idx 49
# loading training instances, dir instances/train_100_n60_m60 idx 50
# loading training instances, dir instances/train_100_n60_m60 idx 51
# loading training instances, dir instances/train_100_n60_m60 idx 52
# loading training instances, dir instances/train_100_n60_m60 idx 53
# loading training instances, dir instances/train_100_n60_m60 idx 54
# loading training instances, dir instances/train_100_n60_m60 idx 55
# loading training instances, dir instances/train_100_n60_m60 idx 56
# loading training instances, dir instances/train_100_n60_m60 idx 57
# loading training instances, dir instances/train_100_n60_m60 idx 58
# loading training instances, dir instances/train_100_n60_m60 idx 59
# loading training instances, dir instances/train_100_n60_m60 idx 60
# loading training instances, dir instances/train_100_n60_m60 idx 61
# loading training instances, dir instances/train_100_n60_m60 idx 62
# loading training instances, dir instances/train_100_n60_m60 idx 63
# loading training instances, dir instances/train_100_n60_m60 idx 64
# loading training instances, dir instances/train_100_n60_m60 idx 65
# loading training instances, dir instances/train_100_n60_m60 idx 66
# loading training instances, dir instances/train_100_n60_m60 idx 67
# loading training instances, dir instances/train_100_n60_m60 idx 68
# loading training instances, dir instances/train_100_n60_m60 idx 69
# loading training instances, dir instances/train_100_n60_m60 idx 70
# loading training instances, dir instances/train_100_n60_m60 idx 71
# loading training instances, dir instances/train_100_n60_m60 idx 72
# loading training instances, dir instances/train_100_n60_m60 idx 73
# loading training instances, dir instances/train_100_n60_m60 idx 74
# loading training instances, dir instances/train_100_n60_m60 idx 75
# loading training instances, dir instances/train_100_n60_m60 idx 76
# loading training instances, dir instances/train_100_n60_m60 idx 77
# loading training instances, dir instances/train_100_n60_m60 idx 78
# loading training instances, dir instances/train_100_n60_m60 idx 79
# loading training instances, dir instances/train_100_n60_m60 idx 80
# loading training instances, dir instances/train_100_n60_m60 idx 81
# loading training instances, dir instances/train_100_n60_m60 idx 82
# loading training instances, dir instances/train_100_n60_m60 idx 83
# loading training instances, dir instances/train_100_n60_m60 idx 84
# loading training instances, dir instances/train_100_n60_m60 idx 85
# loading training instances, dir instances/train_100_n60_m60 idx 86
# loading training instances, dir instances/train_100_n60_m60 idx 87
# loading training instances, dir instances/train_100_n60_m60 idx 88
# loading training instances, dir instances/train_100_n60_m60 idx 89
# loading training instances, dir instances/train_100_n60_m60 idx 90
# loading training instances, dir instances/train_100_n60_m60 idx 91
# loading training instances, dir instances/train_100_n60_m60 idx 92
# loading training instances, dir instances/train_100_n60_m60 idx 93
# loading training instances, dir instances/train_100_n60_m60 idx 94
# loading training instances, dir instances/train_100_n60_m60 idx 95
# loading training instances, dir instances/train_100_n60_m60 idx 96
# loading training instances, dir instances/train_100_n60_m60 idx 97
# loading training instances, dir instances/train_100_n60_m60 idx 98

# %%
# Main (Hard) [Training for 100 episodes] 

tic = time()
for e in range(100):
  tic_e = time()
  s = env.reset()
  d = False
  t = 0
  repisode = 0
  obs_constraints = []
  obs_cuts = []
  acts = []
  rews = []
  epsilon = np.max([np.exp(-0.05*e), 0.1])

  while not d:
    A, b, c, D, d = s
    A, b, D, d = min_max_scaler(A, b, D, d)
    # Aggregate RHS and LHS in the same matrix through concatenation
    avail_constraints = np.concatenate((A, b[:, None]), axis=1)
    gomory_cuts = np.concatenate((D, d[:, None]), axis=1)
    # Use ANN Model to compute probabilities for each action
    prob = actor.compute_prob(avail_constraints, gomory_cuts)
    prob /= np.sum(prob)
    # Epsilon Greedy Exploration
    result = np.random.rand(1)
    if result < epsilon:
      a = np.random.randint(0, s[-1].size, 1)
    else:
      a = [np.random.choice(s[-1].size,  p=prob.flatten())]
    # Take action and get new state, reward and done status
    s, r, d, _ = env.step(list(a))
    obs_constraints.append(avail_constraints)
    obs_cuts.append(gomory_cuts)
    acts.append(a)
    rews.append(r)
    repisode += r
  
  rrecord.append(repisode)
  rewards = discounted_rewards(rews, gamma)
  loss = actor.train(obs_constraints, obs_cuts, acts, rewards)
  toc_e = time()
  print("Episode: ", e, "| Sum Reward: ", np.round(repisode, 3), "| Loss: ", np.round(loss, 3), "| Elapsed Time: ", np.round(toc_e-tic_e), 'seconds')
  loss_record.append(loss)
  reward_record.append(repisode)
  fixedWindow=10
  movingAverage=0
  if len(rrecord) >= fixedWindow:
    movingAverage=np.mean(rrecord[len(rrecord)-fixedWindow:len(rrecord)-1])
    moving_average.append(movingAverage)
toc = time()

print('Time required for training :', toc-tic)
# Out:
# Episode:  0 | Sum Reward:  0.754 | Loss:  39.08 | Elapsed Time:  41.0 seconds
# Episode:  1 | Sum Reward:  0.198 | Loss:  16.78 | Elapsed Time:  48.0 seconds
# Episode:  2 | Sum Reward:  0.625 | Loss:  138.245 | Elapsed Time:  40.0 seconds
# Episode:  3 | Sum Reward:  1.01 | Loss:  259.999 | Elapsed Time:  43.0 seconds
# Episode:  4 | Sum Reward:  0.778 | Loss:  27.779 | Elapsed Time:  44.0 seconds
# Episode:  5 | Sum Reward:  0.259 | Loss:  4.688 | Elapsed Time:  45.0 seconds
# Episode:  6 | Sum Reward:  0.35 | Loss:  44.522 | Elapsed Time:  35.0 seconds
# Episode:  7 | Sum Reward:  0.588 | Loss:  25.07 | Elapsed Time:  40.0 seconds
# Episode:  8 | Sum Reward:  0.341 | Loss:  38.626 | Elapsed Time:  34.0 seconds
# Episode:  9 | Sum Reward:  0.082 | Loss:  2.75 | Elapsed Time:  33.0 seconds
# Episode:  75 | Sum Reward:  1.115 | Loss:  50.898 | Elapsed Time:  34.0 seconds
# Episode:  76 | Sum Reward:  0.72 | Loss:  16.356 | Elapsed Time:  34.0 seconds
# Episode:  77 | Sum Reward:  0.126 | Loss:  5.378 | Elapsed Time:  34.0 seconds
# Episode:  78 | Sum Reward:  0.375 | Loss:  24.066 | Elapsed Time:  34.0 seconds
# Episode:  79 | Sum Reward:  1.101 | Loss:  81.394 | Elapsed Time:  35.0 seconds
# Episode:  80 | Sum Reward:  0.868 | Loss:  6.652 | Elapsed Time:  34.0 seconds
# Episode:  81 | Sum Reward:  0.78 | Loss:  7.428 | Elapsed Time:  34.0 seconds
# Episode:  82 | Sum Reward:  0.615 | Loss:  0.009 | Elapsed Time:  33.0 seconds
# Episode:  83 | Sum Reward:  0.141 | Loss:  0.753 | Elapsed Time:  33.0 seconds
# Episode:  84 | Sum Reward:  0.702 | Loss:  6.912 | Elapsed Time:  33.0 seconds
# Episode:  85 | Sum Reward:  0.335 | Loss:  4.075 | Elapsed Time:  33.0 seconds
# Episode:  86 | Sum Reward:  0.996 | Loss:  6.533 | Elapsed Time:  33.0 seconds
# Episode:  87 | Sum Reward:  1.353 | Loss:  66.647 | Elapsed Time:  33.0 seconds
# Episode:  88 | Sum Reward:  0.487 | Loss:  6.052 | Elapsed Time:  33.0 seconds
# Episode:  89 | Sum Reward:  0.784 | Loss:  13.551 | Elapsed Time:  33.0 seconds
# Episode:  90 | Sum Reward:  1.115 | Loss:  122.866 | Elapsed Time:  34.0 seconds
# Episode:  91 | Sum Reward:  0.708 | Loss:  7.333 | Elapsed Time:  33.0 seconds
# Episode:  92 | Sum Reward:  0.965 | Loss:  5.766 | Elapsed Time:  34.0 seconds
# Episode:  93 | Sum Reward:  0.922 | Loss:  1.036 | Elapsed Time:  33.0 seconds
# Episode:  94 | Sum Reward:  0.465 | Loss:  0.033 | Elapsed Time:  33.0 seconds
# Episode:  95 | Sum Reward:  0.377 | Loss:  0.067 | Elapsed Time:  33.0 seconds
# Episode:  96 | Sum Reward:  0.25 | Loss:  0.001 | Elapsed Time:  33.0 seconds
# Episode:  97 | Sum Reward:  1.195 | Loss:  61.883 | Elapsed Time:  33.0 seconds
# Episode:  98 | Sum Reward:  0.211 | Loss:  12.035 | Elapsed Time:  33.0 seconds
# Episode:  99 | Sum Reward:  0.265 | Loss:  7.82 | Elapsed Time:  33.0 seconds
# Time required for training : 3412.674503803253

# %%
np.mean(reward_record)
# Out:
# 0.6528485811067571

# %%
import matplotlib.pyplot as plt

# %%
# Plot Training Reward
plt.figure(figsize=(10, 5), dpi=100)
plt.plot(reward_record)
plt.grid(color='grey', linestyle=':', linewidth=1)
plt.title('Training Reward')
plt.xlabel('Episode')
plt.ylabel('Total Sum of Rewards')
plt.show()

# %%
# Plot Training Reward Moving Average
plt.figure(figsize=(10, 5), dpi=100)
plt.plot(moving_average)
plt.grid(color='grey', linestyle=':', linewidth=1)
plt.title('Training Reward Moving Average')
plt.xlabel('Episode')
plt.ylabel('Total Sum of Rewards')
plt.show()

# %%
# Plot Training Loss
plt.figure(figsize=(10, 5), dpi=100)
plt.plot(loss_record)
plt.title('Training Loss')
plt.xlabel('Episode')
plt.ylabel('Loss')
plt.show()

# %%
# Create Testing Instances
# !python generate_randomip.py --num-v 60 --num-c 60 --num-instances 100
# Out:
# start generating instances
# Restricted license - for non-production use only - expires 2023-10-25
# num of instances generated: 1
# num of instances generated: 2
# num of instances generated: 3
# num of instances generated: 4
# num of instances generated: 5
# num of instances generated: 6
# num of instances generated: 7
# num of instances generated: 8
# num of instances generated: 9
# num of instances generated: 10
# num of instances generated: 11
# num of instances generated: 12
# num of instances generated: 13
# num of instances generated: 14
# num of instances generated: 15
# num of instances generated: 16
# num of instances generated: 17
# num of instances generated: 18
# num of instances generated: 19
# num of instances generated: 20
# num of instances generated: 21
# num of instances generated: 22
# num of instances generated: 23
# num of instances generated: 24
# num of instances generated: 25
# num of instances generated: 26
# num of instances generated: 27
# num of instances generated: 28
# num of instances generated: 29
# num of instances generated: 30
# num of instances generated: 31
# num of instances generated: 32
# num of instances generated: 33
# num of instances generated: 34
# num of instances generated: 35
# num of instances generated: 36
# num of instances generated: 37
# num of instances generated: 38
# num of instances generated: 39
# num of instances generated: 40
# num of instances generated: 41
# num of instances generated: 42
# num of instances generated: 43
# num of instances generated: 44
# num of instances generated: 45
# num of instances generated: 46
# num of instances generated: 47
# num of instances generated: 48
# num of instances generated: 49
# num of instances generated: 50
# num of instances generated: 51
# num of instances generated: 52
# num of instances generated: 53
# num of instances generated: 54
# num of instances generated: 55
# num of instances generated: 56
# num of instances generated: 57
# num of instances generated: 58
# num of instances generated: 59
# num of instances generated: 60
# num of instances generated: 61
# num of instances generated: 62
# num of instances generated: 63
# num of instances generated: 64
# num of instances generated: 65
# num of instances generated: 66
# num of instances generated: 67
# num of instances generated: 68
# num of instances generated: 69
# num of instances generated: 70
# num of instances generated: 71
# num of instances generated: 72
# num of instances generated: 73
# num of instances generated: 74
# num of instances generated: 75
# num of instances generated: 76
# num of instances generated: 77
# num of instances generated: 78
# num of instances generated: 79
# num of instances generated: 80
# num of instances generated: 81
# num of instances generated: 82
# num of instances generated: 83
# num of instances generated: 84
# num of instances generated: 85
# num of instances generated: 86
# num of instances generated: 87
# num of instances generated: 88
# num of instances generated: 89
# num of instances generated: 90
# num of instances generated: 91
# num of instances generated: 92
# num of instances generated: 93
# num of instances generated: 94
# num of instances generated: 95
# num of instances generated: 96
# num of instances generated: 97
# num of instances generated: 98
# num of instances generated: 99
# num of instances generated: 100

# %%
# Main (Hard) [Testing for 100 different instances]
from testgymenv import make_gurobi_env

instance_name = "randomip_n60_m60"
timelimit = 50
tic = time()

for instance_idx in range(100):
  env = make_gurobi_env('instances/{}'.format(instance_name), instance_idx, timelimit)
  s = env.reset()
  d = False
  repisode = 0
  obs_constraints = []
  obs_cuts = []
  acts = []
  rews = []
  tic_e = time()
  while not d:
    A, b, c, D, d = s
    A, b, D, d = min_max_scaler(A, b, D, d)
    # Aggregate RHS and LHS in the same matrix through concatenation
    avail_constraints = np.concatenate((A, b[:, None]), axis=1)
    gomory_cuts = np.concatenate((D, d[:, None]), axis=1)
    # Use ANN Model to compute probabilities for each action
    prob = actor.compute_prob(avail_constraints, gomory_cuts)
    prob /= np.sum(prob)
    a = [np.random.choice(s[-1].size,  p=prob.flatten())]
    s, r, d, _ = env.step(list(a))
    obs_constraints.append(avail_constraints)
    obs_cuts.append(gomory_cuts)
    acts.append(a)
    rews.append(r)
    repisode += r
  rrecord.append(repisode)
  rewards = discounted_rewards(rews, gamma)
  toc_e = time()
  print("Episode: ", instance_idx, "| Sum Reward: ", np.round(repisode, 3), "| Elapsed Time: ", np.round(toc_e-tic_e), 'seconds')
  reward_record.append(repisode)
  fixedWindow=10
  movingAverage=0
  if len(rrecord) >= fixedWindow:
    movingAverage=np.mean(rrecord[len(rrecord)-fixedWindow:len(rrecord)-1])
    moving_average.append(movingAverage)
toc = time()

print('Time required for testing :', toc-tic)
# Out:
# loading training instances, dir instances/randomip_n60_m60 idx 0
# Episode:  0 | Sum Reward:  0.698 | Elapsed Time:  35.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 1
# Episode:  1 | Sum Reward:  0.171 | Elapsed Time:  27.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 2
# Episode:  2 | Sum Reward:  0.08 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 3
# Episode:  3 | Sum Reward:  0.435 | Elapsed Time:  28.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 4
# Episode:  4 | Sum Reward:  0.073 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 5
# Episode:  5 | Sum Reward:  0.387 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 6
# Episode:  6 | Sum Reward:  0.149 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 7
# Episode:  7 | Sum Reward:  0.625 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 8
# Episode:  8 | Sum Reward:  0.95 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 9
# Episode:  9 | Sum Reward:  0.166 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 10
# Episode:  10 | Sum Reward:  0.535 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 11
# Episode:  11 | Sum Reward:  0.112 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 12
# Episode:  12 | Sum Reward:  0.206 | Elapsed Time:  27.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 13
# Episode:  13 | Sum Reward:  0.116 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 14
# Episode:  14 | Sum Reward:  0.965 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 15
# Episode:  15 | Sum Reward:  0.605 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 16
# Episode:  16 | Sum Reward:  0.181 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 17
# Episode:  17 | Sum Reward:  0.175 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 18
# Episode:  18 | Sum Reward:  0.708 | Elapsed Time:  27.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 19
# Episode:  19 | Sum Reward:  0.383 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 20
# Episode:  20 | Sum Reward:  0.074 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 21
# Episode:  21 | Sum Reward:  0.193 | Elapsed Time:  27.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 22
# Episode:  22 | Sum Reward:  0.151 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 23
# Episode:  23 | Sum Reward:  0.211 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 24
# Episode:  24 | Sum Reward:  0.105 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 25
# Episode:  25 | Sum Reward:  0.083 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 26
# Episode:  26 | Sum Reward:  0.079 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 27
# Episode:  27 | Sum Reward:  0.116 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 28
# Episode:  28 | Sum Reward:  0.328 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 29
# Episode:  29 | Sum Reward:  0.698 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 30
# Episode:  30 | Sum Reward:  0.694 | Elapsed Time:  27.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 31
# Episode:  31 | Sum Reward:  0.801 | Elapsed Time:  27.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 32
# Episode:  32 | Sum Reward:  0.855 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 33
# Episode:  33 | Sum Reward:  0.369 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 34
# Episode:  34 | Sum Reward:  0.287 | Elapsed Time:  27.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 35
# Episode:  35 | Sum Reward:  0.388 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 36
# Episode:  36 | Sum Reward:  0.174 | Elapsed Time:  27.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 37
# Episode:  37 | Sum Reward:  0.109 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 38
# Episode:  38 | Sum Reward:  0.156 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 39
# Episode:  39 | Sum Reward:  1.085 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 40
# Episode:  40 | Sum Reward:  0.304 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 41
# Episode:  41 | Sum Reward:  0.298 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 42
# Episode:  42 | Sum Reward:  0.331 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 43
# Episode:  43 | Sum Reward:  0.067 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 44
# Episode:  44 | Sum Reward:  0.039 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 45
# Episode:  45 | Sum Reward:  1.025 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 46
# Episode:  46 | Sum Reward:  0.156 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 47
# Episode:  47 | Sum Reward:  0.631 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 48
# Episode:  48 | Sum Reward:  0.165 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 49
# Episode:  49 | Sum Reward:  0.86 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 50
# Episode:  50 | Sum Reward:  0.71 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 51
# Episode:  51 | Sum Reward:  0.099 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 52
# Episode:  52 | Sum Reward:  0.476 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 53
# Episode:  53 | Sum Reward:  0.814 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 54
# Episode:  54 | Sum Reward:  0.129 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 55
# Episode:  55 | Sum Reward:  0.141 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 56
# Episode:  56 | Sum Reward:  0.094 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 57
# Episode:  57 | Sum Reward:  0.203 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 58
# Episode:  58 | Sum Reward:  0.186 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 59
# Episode:  59 | Sum Reward:  0.736 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 60
# Episode:  60 | Sum Reward:  0.325 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 61
# Episode:  61 | Sum Reward:  0.085 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 62
# Episode:  62 | Sum Reward:  0.191 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 63
# Episode:  63 | Sum Reward:  0.293 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 64
# Episode:  64 | Sum Reward:  0.282 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 65
# Episode:  65 | Sum Reward:  0.964 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 66
# Episode:  66 | Sum Reward:  0.458 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 67
# Episode:  67 | Sum Reward:  0.154 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 68
# Episode:  68 | Sum Reward:  0.131 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 69
# Episode:  69 | Sum Reward:  0.215 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 70
# Episode:  70 | Sum Reward:  0.188 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 71
# Episode:  71 | Sum Reward:  0.268 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 72
# Episode:  72 | Sum Reward:  0.228 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 73
# Episode:  73 | Sum Reward:  0.443 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 74
# Episode:  74 | Sum Reward:  0.764 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 75
# Episode:  75 | Sum Reward:  0.127 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 76
# Episode:  76 | Sum Reward:  0.135 | Elapsed Time:  27.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 77
# Episode:  77 | Sum Reward:  0.156 | Elapsed Time:  28.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 78
# Episode:  78 | Sum Reward:  0.906 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 79
# Episode:  79 | Sum Reward:  0.838 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 80
# Episode:  80 | Sum Reward:  0.145 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 81
# Episode:  81 | Sum Reward:  0.125 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 82
# Episode:  82 | Sum Reward:  0.131 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 83
# Episode:  83 | Sum Reward:  1.162 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 84
# Episode:  84 | Sum Reward:  0.074 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 85
# Episode:  85 | Sum Reward:  0.582 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 86
# Episode:  86 | Sum Reward:  0.035 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 87
# Episode:  87 | Sum Reward:  0.08 | Elapsed Time:  27.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 88
# Episode:  88 | Sum Reward:  0.211 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 89
# Episode:  89 | Sum Reward:  0.339 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 90
# Episode:  90 | Sum Reward:  0.148 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 91
# Episode:  91 | Sum Reward:  0.831 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 92
# Episode:  92 | Sum Reward:  0.901 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 93
# Episode:  93 | Sum Reward:  0.189 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 94
# Episode:  94 | Sum Reward:  0.897 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 95
# Episode:  95 | Sum Reward:  0.639 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 96
# Episode:  96 | Sum Reward:  0.114 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 97
# Episode:  97 | Sum Reward:  0.296 | Elapsed Time:  27.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 98
# Episode:  98 | Sum Reward:  0.233 | Elapsed Time:  26.0 seconds
# loading training instances, dir instances/randomip_n60_m60 idx 99
# Episode:  99 | Sum Reward:  0.134 | Elapsed Time:  26.0 seconds
# Time required for testing : 2657.031937122345

# %%
# Plot Testing Reward
plt.figure(figsize=(10, 5), dpi=100)
plt.plot(reward_record)
plt.grid(color='grey', linestyle=':', linewidth=1)
plt.title('Testing Reward')
plt.xlabel('Episode')
plt.ylabel('Total Sum of Rewards')
plt.show()

# %%
# Plot Testing Reward Moving Average
plt.figure(figsize=(10, 5), dpi=100)
plt.plot(moving_average)
plt.grid(color='grey', linestyle=':', linewidth=1)
plt.title('Testing Reward Moving Average')
plt.xlabel('Episode')
plt.ylabel('Total Sum of Rewards')
plt.show()
